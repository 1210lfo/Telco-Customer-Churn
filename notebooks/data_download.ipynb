# %% [markdown]
# 📚 **Importar librarerías**

# %%
# librerías base para data science
from pathlib import Path

import pandas as pd

# %% [markdown]
# 💾 **Carga de datos**

# %%
# Cargar los datos
url_data = "https://github.com/JoseRZapata/Data_analysis_notebooks/raw/refs/heads/main/data/datasets/Clientes_Telcomunicaciones-Churn_data.csv"
churn_df = pd.read_csv(url_data, low_memory=False)  # no parsing of mixed types
churn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24742 entries, 0 to 24741
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   MonthlyCharges    24527 non-null  float64
#  1   data_source       24739 non-null  object
#  2   xml               0 non-null      float64
#  3   StreamingMovies   24415 non-null  object
#  4   Partner           24639 non-null  object
#  5   value             24739 non-null  float64
#  6   PhoneService      24527 non-null  object
#  7   InternetService   24445 non-null  object
#  8   StreamingTV       24375 non-null  object
#  9   OnlineSecurity    24393 non-null  object
#  10  PaymentMethod     24502 non-null  object
#  11  MultipleLines     24493 non-null  object
#  12  Dependents        24585 non-null  object
#  13  DeviceProtection  24383 non-null  object
#  14  OnlineSecurity    24393 non-null  object
#  15  SeniorCitizen     24636 non-null  float64
# ...

# %%
# Vamos a mirar algunos registros
churn_df.sample(10)
# Out:
#        MonthlyCharges data_source  xml      StreamingMovies Partner     value  \
# 15083           79.85       other  NaN                   No      No  151642.0
# 4742            25.40       other  NaN  No internet service     Yes  151642.0
# 10682           74.85       other  NaN                  Yes     Yes  151642.0
# 20013           70.25       other  NaN                  NaN      No  151642.0
# 6380           115.65       other  NaN                  Yes      No  151642.0
# 16530           19.95       other  NaN  No internet service     Yes  151642.0
# 14665           55.15       other  NaN                   No     Yes  151642.0
# 23053           98.85       other  NaN                  Yes     Yes  151642.0
# 10114           53.10       other  NaN                   No     Yes  151642.0
# 14031           89.00       other  NaN                  Yes     Yes  151642.0
#
#       PhoneService InternetService          StreamingTV       OnlineSecurity  \
# ...

# %% [markdown]
# 📊 **Información del dataset**

# %%
# Miremos si todas las columnas de este dataset son útiles
churn_df.columns
# Out:
# Index(['MonthlyCharges', 'data_source', 'xml', 'StreamingMovies', 'Partner',
#        'value', 'PhoneService', 'InternetService', 'StreamingTV',
#        'OnlineSecurity', 'PaymentMethod ', 'MultipleLines', 'Dependents',
#        'DeviceProtection', 'OnlineSecurity ', 'SeniorCitizen', 'TotalCharges',
#        'TechSupport', 'gender ', 'PaperlessBilling', 'gender', 'tenure',
#        'Churn', 'OnlineBackup', 'PaymentMethod', 'Contract', 'customerID',
#        'Churn '],
#       dtype='object')

# %% [markdown]
# Desde este momento podemos ver que existen algunas columnas que tienen su nombre replicado y podríamos comenzar a descartarlas. Columnas como:
#
#     -'Churn' y 'Churn '
#     -'gender' y 'gender '
#     -'PaymentMethod' y 'PaymentMethod '
#     -'OnlineSecurity' y 'OnlineSecurity '

# %%
# Lista de columnas específicas a analizar
primera_mitad = [
    "MonthlyCharges",
    "data_source",
    "xml",
    "StreamingMovies",
    "Partner",
    "value",
    "PhoneService",
    "InternetService",
    "StreamingTV",
    "OnlineSecurity",
    "PaymentMethod ",
    "MultipleLines",
    "Dependents",
    "DeviceProtection",
    "OnlineSecurity ",
    "SeniorCitizen",
]
segunda_mitad = [
    "TotalCharges",
    "TechSupport",
    "gender ",
    "PaperlessBilling",
    "gender",
    "tenure",
    "Churn",
    "Churn ",
    "OnlineBackup",
    "PaymentMethod",
    "Contract",
    "customerID",
]

# crear los subdatasets
df_subset1 = churn_df[primera_mitad]
df_subset2 = churn_df[segunda_mitad]

# obtener la información de la primera mitad de las columnas
df_subset1.info()
df_subset1.sample(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24742 entries, 0 to 24741
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   MonthlyCharges    24527 non-null  float64
#  1   data_source       24739 non-null  object
#  2   xml               0 non-null      float64
#  3   StreamingMovies   24415 non-null  object
#  4   Partner           24639 non-null  object
#  5   value             24739 non-null  float64
#  6   PhoneService      24527 non-null  object
#  7   InternetService   24445 non-null  object
#  8   StreamingTV       24375 non-null  object
#  9   OnlineSecurity    24393 non-null  object
#  10  PaymentMethod     24502 non-null  object
#  11  MultipleLines     24493 non-null  object
#  12  Dependents        24585 non-null  object
#  13  DeviceProtection  24383 non-null  object
#  14  OnlineSecurity    24393 non-null  object
#  15  SeniorCitizen     24636 non-null  float64
# ...

# %% [markdown]
# Parece ser que la columna 'xml' no tiene ningún tipo de contenido por lo que es la mejor cnadidata para ser descartada.

# %%
churn_df["Churn"].equals(churn_df["Churn "])
# Out:
# True

# %%
churn_df["OnlineSecurity"].equals(churn_df["OnlineSecurity "])
# Out:
# True

# %%
churn_df["PaymentMethod"].equals(churn_df["PaymentMethod "])
# Out:
# True

# %%
churn_df["gender"].equals(churn_df["gender "])
# Out:
# True

# %%
# obtener la información de la segunda mitad de las columnas
df_subset2.info()
df_subset2.sample(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24742 entries, 0 to 24741
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   TotalCharges      24601 non-null  object
#  1   TechSupport       24379 non-null  object
#  2   gender            24684 non-null  object
#  3   PaperlessBilling  24504 non-null  object
#  4   gender            24684 non-null  object
#  5   tenure            24562 non-null  float64
#  6   Churn             24571 non-null  object
#  7   Churn             24571 non-null  object
#  8   OnlineBackup      24374 non-null  object
#  9   PaymentMethod     24502 non-null  object
#  10  Contract          24504 non-null  object
#  11  customerID        24689 non-null  object
# dtypes: float64(1), object(11)
# memory usage: 2.3+ MB
#       TotalCharges TechSupport gender  PaperlessBilling gender  tenure Churn  \
# ...

# %%
# Reseleccionar cuales columnas utilizar eliminando las duplicadas o nulas
columns_to_use = [
    "customerID",
    "MonthlyCharges",
    "data_source",
    "StreamingMovies",
    "Partner",
    "value",
    "PhoneService",
    "InternetService",
    "StreamingTV",
    "OnlineSecurity",
    "PaymentMethod",
    "MultipleLines",
    "Dependents",
    "DeviceProtection",
    "SeniorCitizen",
    "TotalCharges",
    "TechSupport",
    "gender ",
    "PaperlessBilling",
    "tenure",
    "OnlineBackup",
    "Contract",
    "Churn",
]

# %%
churn_final_df = pd.read_csv(url_data, usecols=columns_to_use, low_memory=False)
churn_final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24742 entries, 0 to 24741
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   MonthlyCharges    24527 non-null  float64
#  1   data_source       24739 non-null  object
#  2   StreamingMovies   24415 non-null  object
#  3   Partner           24639 non-null  object
#  4   value             24739 non-null  float64
#  5   PhoneService      24527 non-null  object
#  6   InternetService   24445 non-null  object
#  7   StreamingTV       24375 non-null  object
#  8   OnlineSecurity    24393 non-null  object
#  9   MultipleLines     24493 non-null  object
#  10  Dependents        24585 non-null  object
#  11  DeviceProtection  24383 non-null  object
#  12  SeniorCitizen     24636 non-null  float64
#  13  TotalCharges      24601 non-null  object
#  14  TechSupport       24379 non-null  object
#  15  gender            24684 non-null  object
# ...

# %% [markdown]
# Al final se eliminaron las siguientes columnas:
# 'PaymentMethod ', 'gender ', 'OnlineSecurity ', 'Churn ' y 'xml'

# %% [markdown]
# **Save dataset in local format**

# %%
# Define el directorio base
BASE_DIR = Path("/home/lof/Projects/Telco-Customer-Churn")

# Define el directorio de datos
DATA_DIR = BASE_DIR / "data" / "raw"
file_path = DATA_DIR / "churn_raw.csv"

# %%
churn_final_df.to_csv(file_path, index=False)

# %% [markdown]
# **Resultados**
#
# El dataset se guardará en formato parquet y se seleccionan las columnas que se van a utilizar en el proyecto.
#
# ruta: /home/lof/Projects/Telco-Customer-Churn/data/raw/churn_raw.csv

# %% [markdown]
# **Preguntas y Respuestas**
#
# ### 1. **¿Cuál es el objetivo del problema?**
#    - **Respuesta**: Predecir el comportamiento de los clientes de una compañía de telecomunicaciones para identificar a aquellos con mayor probabilidad de abandonar (Churn) y así implementar estrategias para retenerlos.
#
# ---
#
# ### 2. **¿Cómo se usará su solución?**
#    - **Respuesta**: La solución se utilizará para retener clientes dentro de la compañía al identificar a los clientes en riesgo de abandonar y ofrecerles incentivos personalizados, mejoras en el servicio o promociones especiales.
#
# ---
#
# ### 3. **¿Cuáles son las soluciones actuales (si las hay)?**
#    - **Respuesta**: Según el contexto proporcionado, no hay soluciones actuales implementadas para abordar el problema de Churn en la compañía.
#
# ---
#
# ### 4. **¿Cómo se debe enmarcar este problema (supervisado / no supervisado, en línea / fuera de línea, etc.)?**
#    - **Respuesta**: Este problema se puede enmarcar de la siguiente manera:
#      - **Aprendizaje supervisado**: Para predecir qué clientes tienen mayor probabilidad de abandonar (Churn) utilizando datos históricos etiquetados.
#      - **Aprendizaje no supervisado**: Para agrupar clientes con características similares y descubrir patrones ocultos que puedan ayudar a diseñar estrategias de retención personalizadas.
#      - **Fuera de línea**: El análisis y la construcción del modelo se realizarán con datos históricos, pero la implementación podría ser en línea para predecir Churn en tiempo real.
#
# ---
#
# ### 5. **¿Cómo se debe medir el desempeño o el rendimiento de la solución, una primera intuición?**
#    - **Respuesta**: La medida de desempeño inicial podría ser:
#      - **Tasa de precisión (Accuracy)**: Para evaluar cuántos clientes fueron correctamente clasificados como Churn o No Churn.
#      - **Reducción en la tasa de Churn**: Medir el porcentaje de clientes retenidos después de implementar la solución.
#
# ---
#
# ### 6. **¿La medida de desempeño está alineada con el objetivo del problema?**
#    - **Respuesta**: Sí, las métricas propuestas (Accuracy y reducción en la tasa de Churn) están alineadas con el objetivo de predecir y retener clientes.
#
# ---
#
# ### 7. **¿Cuál sería el desempeño o rendimiento mínimo necesario para alcanzar el objetivo del problema?**
#    - **Respuesta**: Un desempeño mínimo aceptable podría ser:
#      - **Reducción del 20% en la tasa de Churn**: Es decir, retener al menos a un 20% de los clientes que habrían abandonado sin la solución.
#
# ---
#
# ### 8. **¿Cuáles son los problemas parecidos? ¿Se puede reutilizar experiencias o herramientas ya creadas?**
#    - **Respuesta**: Problemas similares incluyen:
#      - Predicción de abandono en servicios de streaming, banca o seguros.
#      - Herramientas reutilizables:
#        - Algoritmos de clasificación como Regresión Logística, Random Forest, XGBoost o Redes Neuronales.
#        - Plataformas de análisis de datos como Python (pandas, scikit-learn) o R.
#        - Herramientas de visualización como Tableau o Power BI para presentar insights.
#
# ---
#
# ### 9. **¿Hay experiencia del problema disponible?**
#    - **Respuesta**: Sí, el dataset proporciona información histórica sobre clientes, incluyendo:
#      - Servicios contratados (teléfono, internet, etc.).
#      - Información de la cuenta (contrato, facturación, cargos).
#      - Datos demográficos (género, edad, dependientes).
#      - Columna `Churn` que indica si el cliente abandonó o no.
#
# ---
#
# ### 10. **¿Cómo se puede resolver el problema manualmente?**
#    - **Respuesta**: Manualmente, se podría:
#      1. Analizar los datos históricos para identificar patrones comunes entre los clientes que abandonaron.
#      2. Crear segmentos de clientes basados en características como tipo de contrato, servicios contratados o cargos mensuales.
#      3. Contactar a los clientes en riesgo con ofertas personalizadas o mejoras en el servicio.
#      4. Realizar encuestas para entender las razones del abandono y ajustar las estrategias.
#
# ---
#
# ### 11. **Listado de supuestos hasta este momento**
#    - **Supuestos**:
#      1. Los datos del dataset son representativos del comportamiento real de los clientes.
#      2. Las características proporcionadas (servicios, facturación, demografía) son suficientes para predecir el Churn.
#      3. Los clientes en riesgo de abandonar responderán positivamente a las estrategias de retención.
#      4. La implementación de la solución no generará costos adicionales significativos para la compañía.
#      5. El modelo de predicción será lo suficientemente preciso para justificar su implementación.
